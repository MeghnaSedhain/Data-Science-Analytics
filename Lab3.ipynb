# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghnaSedhain/Data-Science-Analytics/blob/main/Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lab 4: Chi-squared Test of independence in python
#Step 1:Import required libraries
import pandas as pd
from scipy.stats import chi2_contingency

# %%
#step 2:Create the observed frequency  (contigency) table
#example:gender vs product preference
data = {
    "Like": [30, 20],
    "Dislike": [10, 40]
}

# %%
observed= pd.DataFrame(data,index=["Male","Female"])
print("Observed Frequency Table:")
print(observed)
# Out:
# Observed Frequency Table:
#         Like  Dislike
# Male      30       10
# Female    20       40

# %%
#Step 3:Perform Chi-squared Test
chi2_stat,p_val,dof,expected=chi2_contingency(observed)

# %%
# Step 4: Display results
print("\nChi-Square Statistic:", chi2_stat)
print("Degrees of Freedom:", dof)
print("P-Value:", p_val)

print("\nExpected Frequency Table:")
print(pd.DataFrame(expected, index=observed.index, columns=observed.columns))
# Out:
# Chi-Square Statistic: 15.041666666666666
# Degrees of Freedom: 1
# P-Value: 0.00010516355403363098
#
# Expected Frequency Table:
#         Like  Dislike
# Male    20.0     20.0
# Female  30.0     30.0

# %%
# Step 5: Hypothesis decision
alpha = 0.05

if p_val < alpha:
    print("\nReject the Null Hypothesis")
    print("--> There is a significant association between the variables.")
else:
    print("\nFail to reject the Null Hypothesis")
    print("--> There is no significant association between the variables.")
# Out:
# Reject the Null Hypothesis
# --> There is a significant association between the variables.

# %%
data = {
    "Likes p_momo": [8,75,1],
    "Likes c_momo": [63,3,0],
    "Likes v_momo":[23,19,3]
}

# %%
observed= pd.DataFrame(data,index=["Male","Female","Other"])
print("Observed Frequency Table:")
print(observed)
# Out:
# Observed Frequency Table:
#         Likes p_momo  Likes c_momo  Likes v_momo
# Male               8            63            23
# Female            75             3            19
# Other              1             0             3

# %%
#Step 3:Perform Chi-squared Test
chi2_stat,p_val,dof,expected=chi2_contingency(observed)

# %%
# Step 4: Display results
print("\nChi-Square Statistic:", chi2_stat)
print("Degrees of Freedom:", dof)
print("P-Value:", p_val)

print("\nExpected Frequency Table:")
print(pd.DataFrame(expected, index=observed.index, columns=observed.columns))
# Out:
# Chi-Square Statistic: 117.06860193528047
# Degrees of Freedom: 4
# P-Value: 2.257581025851215e-24
#
# Expected Frequency Table:
#         Likes p_momo  Likes c_momo  Likes v_momo
# Male       40.492308     31.815385     21.692308
# Female     41.784615     32.830769     22.384615
# Other       1.723077      1.353846      0.923077

# %%
# Step 5: Hypothesis decision
alpha = 0.05

if p_val < alpha:
    print("\nReject the Null Hypothesis")
    print("--> There is a significant association between the variables.")
else:
    print("\nFail to reject the Null Hypothesis")
    print("--> There is no significant association between the variables.")
# Out:
# Reject the Null Hypothesis
# --> There is a significant association between the variables.
